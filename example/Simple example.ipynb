# %%
using Sellmeier

# %%
BK7
# Out:
# Sellmeier.Medium([1.03961212,0.231792344,1.01046945],[0.00600069867,0.0200179144,103.560653])

# %%
using PyPlot
matplotlib[:rcdefaults]()

# %%
# Wavelength is expected to be in meters
lambda = linspace(0.2,2.5,1000)*1e-6
# Out:
# linspace(1.9999999999999996e-7,2.4999999999999998e-6,1000)

# %%
plot(lambda*1e9,n(BK7,lambda))
xlabel(L"$\lambda$ [nm]")
ylabel(L"$n(\lambda)$")
gcf()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9052cf1320>)
